# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshitha8778/YOLO-practice/blob/main/Model_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/MyDrive/ocean dataset/Aquarium Combined.v2-raw-1024.yolov8"
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# !pip install ultralytics

# %%
import torch
torch.cuda.is_available(), torch.cuda.get_device_name(0)
# Out:
# (True, 'Tesla T4')

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
model.train(
    data="/content/drive/MyDrive/ocean dataset/Aquarium Combined.v2-raw-1024.yolov8/data.yaml",
    epochs=50
)

# %%
# 1️⃣ Zip the results folder
# !zip -r train2_results.zip /content/runs/detect/train2

# 2️⃣ Import files and download
from google.colab import files
files.download("train2_results.zip")
# Out:
# updating: content/runs/detect/train2/ (stored 0%)
# updating: content/runs/detect/train2/val_batch1_labels.jpg (deflated 5%)
# updating: content/runs/detect/train2/BoxR_curve.png (deflated 7%)
# updating: content/runs/detect/train2/train_batch2.jpg (deflated 3%)
# updating: content/runs/detect/train2/train_batch1120.jpg (deflated 7%)
# updating: content/runs/detect/train2/train_batch1121.jpg (deflated 9%)
# updating: content/runs/detect/train2/val_batch2_labels.jpg (deflated 4%)
# updating: content/runs/detect/train2/val_batch1_pred.jpg (deflated 4%)
# updating: content/runs/detect/train2/BoxPR_curve.png (deflated 9%)
# updating: content/runs/detect/train2/confusion_matrix.png (deflated 22%)
# updating: content/runs/detect/train2/confusion_matrix_normalized.png (deflated 19%)
# updating: content/runs/detect/train2/train_batch1.jpg (deflated 3%)
# updating: content/runs/detect/train2/labels.jpg (deflated 25%)
# updating: content/runs/detect/train2/val_batch2_pred.jpg (deflated 4%)
# ...

# %%
from ultralytics import YOLO
model = YOLO("/content/runs/detect/train2/weights/best.pt")
model.val(
    data="/content/drive/MyDrive/ocean dataset/Aquarium Combined.v2-raw-1024.yolov8/data.yaml"
)

# %%
# !ls /content/runs/detect/train2/weights/

# %%
# !ls /content/drive/MyDrive/ocean\ dataset/
# Out:
# 'Aquarium Combined.v2-raw-1024.yolov8'	 test_images

# %%
from ultralytics import YOLO
model = YOLO("/content/runs/detect/train2/weights/best.pt")
model.predict(
    source="/content/drive/MyDrive/ocean dataset/test_images",
    save=True,
    conf=0.5
)
# Out:
# image 1/4 /content/drive/MyDrive/ocean dataset/test_images/Discover the mesmerizing beauty of jellyfish with….jpeg: 640x384 (no detections), 9.3ms
# image 2/4 /content/drive/MyDrive/ocean dataset/test_images/IMG_2395_jpeg_jpg.rf.9f1503ad3b7a7c7938daed057cc4e9bc.jpg: 640x480 5 fishs, 10.8ms
# image 3/4 /content/drive/MyDrive/ocean dataset/test_images/download.jpeg: 640x448 1 penguin, 10.9ms
# image 4/4 /content/drive/MyDrive/ocean dataset/test_images/puffy.jpeg: 640x640 1 jellyfish, 10.3ms
# Speed: 3.5ms preprocess, 10.3ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'fish', 1: 'jellyfish', 2: 'penguin', 3: 'puffin', 4: 'shark', 5: 'starfish', 6: 'stingray'}
#  obb: None
#  orig_img: array([[[218, 136,  11],
#          [218, 136,  11],
# ...

# %%
# 1️⃣ Zip the results folder
# !zip -r train2_results.zip /content/runs/detect/predict2/

# 2️⃣ Import files and download
from google.colab import files
files.download("train2_results.zip")
# Out:
#   adding: content/runs/detect/predict2/ (stored 0%)
#   adding: content/runs/detect/predict2/puffy.jpg (deflated 7%)
#   adding: content/runs/detect/predict2/Discover the mesmerizing beauty of jellyfish with….jpg (deflated 3%)
#   adding: content/runs/detect/predict2/IMG_2395_jpeg_jpg.rf.9f1503ad3b7a7c7938daed057cc4e9bc.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/download.jpg (deflated 6%)

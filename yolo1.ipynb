# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")

# %% [markdown]
# *YOLO*
# -
# YOU ONLY LOOK ONCE PYTHON LIBRARY FOR REAL TIME OBJECT DETECTION

# %% [markdown]
# *BEGIN WITH CREATING A VIRTUAL ENVIRONMENT IN WHICH YOU DOWNLOAD ULTRALYTICS*
# - cd "C:\Users\user\OneDrive\Desktop\CodeInVSC\YOLOOO\YOLO\YOLO-practice"
# - py-3.10 -m venv hvenv
# - hvenv\Scripts\activate
# - python -m pip install --upgrade pip
# - pip install ultralytics

# %% [markdown]
# *TASKS*
# -
# detect, segment, classify

# %% [markdown]
# *MODES*
# -
# train, val, predict

# %% [markdown]
# *MODEL*
# -
# yolov8n-pt, yolov8n-seg.pt,yolov8n-cls.pt

# %% [markdown]
# *implement YOLO in cmd*
# -
# - yolo task = detect mode = predict model =yolov8n.pt source= "C:\Users\user\OneDrive\Desktop\CodeInVSC\YOLOOO\YOLO\YOLO-practice\hvenv\images\download.jpeg"
#  - yolo task = segment mode = predict model = yolov8n-seg.pt source = "C:\Users\user\OneDrive\Desktop\CodeInVSC\YOLOOO\YOLO\YOLO-practice\hvenv\images\download.jpeg"
#  - yolo task = classify mode = predict model = yolov8n-cls.pt source = "C:\Users\user\OneDrive\Desktop\CodeInVSC\YOLOOO\YOLO\YOLO-practice\hvenv\images\download.jpeg"

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')
model.predict(source="images\download.jpeg")
# Out:
# image 1/1 c:\Users\user\Desktop\CodeInVSC\YOLOOO\YOLO\YOLO-practice\images\download.jpeg: 640x480 4 cats, 1 bed, 107.0ms
# Speed: 4.3ms preprocess, 107.0ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 480)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
from ultralytics import YOLO
model = YOLO('yolov8n-seg.pt')
model.predict(source="images\download.jpeg")
# Out:
# image 1/1 c:\Users\user\Desktop\CodeInVSC\YOLOOO\YOLO\YOLO-practice\images\download.jpeg: 640x480 3 cats, 1 bed, 90.7ms
# Speed: 3.0ms preprocess, 90.7ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
# ...
